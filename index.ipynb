# %% [markdown]
# # Model to Predict Housing Prices in Austin, TX
#
# This project will use a Long Short-Term Memory neural network model.
#
# The dataset includes house sale prices, unemployment rates, median household income, city population and mortgage interest rates from Feb. 2008 to Dec 2019

# %%
import pandas as pd
from matplotlib import pyplot
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense

from numpy import concatenate
from math import sqrt
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv('austin_data.csv')
df.head()
# Out:
#       Date   Price  Unemployment  Income  Population  Interest
# 0  2/29/08  185000           3.8   59221     1268000      5.92
# 1  3/31/08  190000           3.8   59221     1268000      5.92
# 2  4/30/08  191500           3.4   59221     1268000      5.92
# 3  5/31/08  198250           3.9   59221     1268000      5.92
# 4  6/30/08  197500           4.4   59221     1268000      5.92

# %% [markdown]
# # Data Preprocessing
#
# Set the date column to pandas datetime format and make it the index.

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)
df.head()
# Out:
#              Price  Unemployment  Income  Population  Interest
# Date
# 2008-02-29  185000           3.8   59221     1268000      5.92
# 2008-03-31  190000           3.8   59221     1268000      5.92
# 2008-04-30  191500           3.4   59221     1268000      5.92
# 2008-05-31  198250           3.9   59221     1268000      5.92
# 2008-06-30  197500           4.4   59221     1268000      5.92

# %% [markdown]
# Plot each feature over time.

# %%
values = df.values
# specify columns to plot
groups = [0, 1, 2, 3, 4]
i = 1
# plot each column
pyplot.figure()
for group in groups:
	pyplot.subplot(len(groups), 1, i)
	pyplot.plot(values[:, group])
	pyplot.title(df.columns[group], y=0.5, loc='right')
	i += 1
pyplot.show()

# %% [markdown]
# Convert the feature series to supervised learning.

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
# frame as supervised learning
reframed = series_to_supervised(scaled, 1, 1)
# drop columns we don't want to predict
reframed.drop(reframed.columns[[6, 7, 8, 9]], axis=1, inplace=True)
print(reframed.head())
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)   var1(t)
# 1   0.062616   0.277778   0.137921        0.0        1.0  0.093924
# 2   0.093924   0.277778   0.137921        0.0        1.0  0.103316
# 3   0.103316   0.203704   0.137921        0.0        1.0  0.145582
# 4   0.145582   0.296296   0.137921        0.0        1.0  0.140886
# 5   0.140886   0.388889   0.137921        0.0        1.0  0.125232

# %% [markdown]
# Split the data into train and test sets.

# %%
values = reframed.values
n_train_months = 8 * 12
train = values[:n_train_months, :]
test = values[n_train_months:, :]

train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]

train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (96, 1, 5) (96,) (46, 1, 5) (46,)

# %% [markdown]
# # Building the model
#
# Fit the LSTM model that uses 50 epochs, a batch size of 72 and two hidden layers. Then plot the loss and validation loss.

# %%
model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')


history = model.fit(train_X, train_y, epochs=50, batch_size=72, validation_data=(test_X, test_y), verbose=2, shuffle=False)

pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# Train on 96 samples, validate on 46 samples
# Epoch 1/50
#  - 1s - loss: 0.2312 - val_loss: 0.7330
# Epoch 2/50
#  - 0s - loss: 0.2168 - val_loss: 0.7151
# Epoch 3/50
#  - 0s - loss: 0.2034 - val_loss: 0.6966
# Epoch 4/50
#  - 0s - loss: 0.1900 - val_loss: 0.6780
# Epoch 5/50
#  - 0s - loss: 0.1779 - val_loss: 0.6596
# Epoch 6/50
#  - 0s - loss: 0.1667 - val_loss: 0.6411
# Epoch 7/50
#  - 0s - loss: 0.1569 - val_loss: 0.6227
# Epoch 8/50
#  - 0s - loss: 0.1479 - val_loss: 0.6042
# Epoch 9/50
#  - 0s - loss: 0.1398 - val_loss: 0.5859
# Epoch 10/50
#  - 0s - loss: 0.1342 - val_loss: 0.5679
# Epoch 11/50
#  - 0s - loss: 0.1302 - val_loss: 0.5503
# Epoch 12/50
#  - 0s - loss: 0.1273 - val_loss: 0.5332
# Epoch 13/50
#  - 0s - loss: 0.1257 - val_loss: 0.5166
# Epoch 14/50
#  - 0s - loss: 0.1244 - val_loss: 0.5006
# Epoch 15/50
#  - 0s - loss: 0.1229 - val_loss: 0.4848
# Epoch 16/50
#  - 0s - loss: 0.1213 - val_loss: 0.4694
# Epoch 17/50
#  - 0s - loss: 0.1200 - val_loss: 0.4543
# Epoch 18/50
#  - 0s - loss: 0.1185 - val_loss: 0.4393
# Epoch 19/50
#  - 0s - loss: 0.1172 - val_loss: 0.4244
# Epoch 20/50
#  - 0s - loss: 0.1158 - val_loss: 0.4098
# Epoch 21/50
#  - 0s - loss: 0.1144 - val_loss: 0.3952
# Epoch 22/50
#  - 0s - loss: 0.1131 - val_loss: 0.3808
# Epoch 23/50
#  - 0s - loss: 0.1119 - val_loss: 0.3666
# Epoch 24/50
#  - 0s - loss: 0.1106 - val_loss: 0.3525
# Epoch 25/50
#  - 0s - loss: 0.1095 - val_loss: 0.3386
# Epoch 26/50
#  - 0s - loss: 0.1083 - val_loss: 0.3249
# Epoch 27/50
#  - 0s - loss: 0.1071 - val_loss: 0.3114
# Epoch 28/50
#  - 0s - loss: 0.1059 - val_loss: 0.2980
# Epoch 29/50
#  - 0s - loss: 0.1047 - val_loss: 0.2848
# Epoch 30/50
#  - 0s - loss: 0.1035 - val_loss: 0.2717
# Epoch 31/50
#  - 0s - loss: 0.1021 - val_loss: 0.2587
# Epoch 32/50
#  - 0s - loss: 0.1007 - val_loss: 0.2457
# Epoch 33/50
#  - 0s - loss: 0.0993 - val_loss: 0.2328
# Epoch 34/50
#  - 0s - loss: 0.0979 - val_loss: 0.2200
# Epoch 35/50
#  - 0s - loss: 0.0963 - val_loss: 0.2071
# Epoch 36/50
#  - 0s - loss: 0.0948 - val_loss: 0.1942
# Epoch 37/50
#  - 0s - loss: 0.0932 - val_loss: 0.1814
# Epoch 38/50
#  - 0s - loss: 0.0916 - val_loss: 0.1686
# Epoch 39/50
#  - 0s - loss: 0.0900 - val_loss: 0.1562
# Epoch 40/50
#  - 0s - loss: 0.0886 - val_loss: 0.1443
# Epoch 41/50
#  - 0s - loss: 0.0870 - val_loss: 0.1329
# Epoch 42/50
#  - 0s - loss: 0.0853 - val_loss: 0.1222
# Epoch 43/50
#  - 0s - loss: 0.0834 - val_loss: 0.1125
# Epoch 44/50
#  - 0s - loss: 0.0814 - val_loss: 0.1046
# Epoch 45/50
#  - 0s - loss: 0.0791 - val_loss: 0.0981
# Epoch 46/50
#  - 0s - loss: 0.0762 - val_loss: 0.0929
# Epoch 47/50
#  - 0s - loss: 0.0730 - val_loss: 0.0889
# Epoch 48/50
#  - 0s - loss: 0.0693 - val_loss: 0.0857
# Epoch 49/50
#  - 0s - loss: 0.0654 - val_loss: 0.0832
# Epoch 50/50
#  - 0s - loss: 0.0613 - val_loss: 0.0812

# %% [markdown]
# The train and test sets took a long time to converge. Next, calculated RMSE. The predictions and actual targets needed to be inverse scaled.

# %%
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

ainv_yhat = concatenate((yhat, test_X[:, 1:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]

test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, 1:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]

rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 14427.645

# %% [markdown]
# This version is trained on ten years of data.

# %%
values = reframed.values
n_train_months = 10 * 12
train = values[:n_train_months, :]
test = values[n_train_months:, :]

train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]

train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (120, 1, 5) (120,) (22, 1, 5) (22,)

# %%
model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')

history = model.fit(train_X, train_y, epochs=50, batch_size=72, validation_data=(test_X, test_y), verbose=2, shuffle=False)

pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# Train on 120 samples, validate on 22 samples
# Epoch 1/50
#  - 1s - loss: 0.3558 - val_loss: 0.9392
# Epoch 2/50
#  - 0s - loss: 0.3409 - val_loss: 0.9169
# Epoch 3/50
#  - 0s - loss: 0.3254 - val_loss: 0.8947
# Epoch 4/50
#  - 0s - loss: 0.3109 - val_loss: 0.8725
# Epoch 5/50
#  - 0s - loss: 0.2976 - val_loss: 0.8505
# Epoch 6/50
#  - 0s - loss: 0.2853 - val_loss: 0.8286
# Epoch 7/50
#  - 0s - loss: 0.2740 - val_loss: 0.8069
# Epoch 8/50
#  - 0s - loss: 0.2643 - val_loss: 0.7855
# Epoch 9/50
#  - 0s - loss: 0.2562 - val_loss: 0.7647
# Epoch 10/50
#  - 0s - loss: 0.2495 - val_loss: 0.7447
# Epoch 11/50
#  - 0s - loss: 0.2442 - val_loss: 0.7256
# Epoch 12/50
#  - 0s - loss: 0.2396 - val_loss: 0.7072
# Epoch 13/50
#  - 0s - loss: 0.2354 - val_loss: 0.6893
# Epoch 14/50
#  - 0s - loss: 0.2311 - val_loss: 0.6721
# Epoch 15/50
#  - 0s - loss: 0.2268 - val_loss: 0.6552
# Epoch 16/50
#  - 0s - loss: 0.2225 - val_loss: 0.6386
# Epoch 17/50
#  - 0s - loss: 0.2182 - val_loss: 0.6222
# Epoch 18/50
#  - 0s - loss: 0.2139 - val_loss: 0.6059
# Epoch 19/50
#  - 0s - loss: 0.2096 - val_loss: 0.5897
# Epoch 20/50
#  - 0s - loss: 0.2055 - val_loss: 0.5737
# Epoch 21/50
#  - 0s - loss: 0.2013 - val_loss: 0.5577
# Epoch 22/50
#  - 0s - loss: 0.1973 - val_loss: 0.5419
# Epoch 23/50
#  - 0s - loss: 0.1932 - val_loss: 0.5262
# Epoch 24/50
#  - 0s - loss: 0.1892 - val_loss: 0.5105
# Epoch 25/50
#  - 0s - loss: 0.1852 - val_loss: 0.4948
# Epoch 26/50
#  - 0s - loss: 0.1812 - val_loss: 0.4791
# Epoch 27/50
#  - 0s - loss: 0.1773 - val_loss: 0.4636
# Epoch 28/50
#  - 0s - loss: 0.1734 - val_loss: 0.4480
# Epoch 29/50
#  - 0s - loss: 0.1695 - val_loss: 0.4325
# Epoch 30/50
#  - 0s - loss: 0.1655 - val_loss: 0.4169
# Epoch 31/50
#  - 0s - loss: 0.1617 - val_loss: 0.4014
# Epoch 32/50
#  - 0s - loss: 0.1578 - val_loss: 0.3860
# Epoch 33/50
#  - 0s - loss: 0.1540 - val_loss: 0.3705
# Epoch 34/50
#  - 0s - loss: 0.1502 - val_loss: 0.3553
# Epoch 35/50
#  - 0s - loss: 0.1464 - val_loss: 0.3401
# Epoch 36/50
#  - 0s - loss: 0.1426 - val_loss: 0.3250
# Epoch 37/50
#  - 0s - loss: 0.1387 - val_loss: 0.3100
# Epoch 38/50
#  - 0s - loss: 0.1348 - val_loss: 0.2949
# Epoch 39/50
#  - 0s - loss: 0.1308 - val_loss: 0.2798
# Epoch 40/50
#  - 0s - loss: 0.1267 - val_loss: 0.2645
# Epoch 41/50
#  - 0s - loss: 0.1225 - val_loss: 0.2491
# Epoch 42/50
#  - 0s - loss: 0.1183 - val_loss: 0.2335
# Epoch 43/50
#  - 0s - loss: 0.1141 - val_loss: 0.2179
# Epoch 44/50
#  - 0s - loss: 0.1100 - val_loss: 0.2023
# Epoch 45/50
#  - 0s - loss: 0.1058 - val_loss: 0.1867
# Epoch 46/50
#  - 0s - loss: 0.1015 - val_loss: 0.1711
# Epoch 47/50
#  - 0s - loss: 0.0974 - val_loss: 0.1557
# Epoch 48/50
#  - 0s - loss: 0.0934 - val_loss: 0.1407
# Epoch 49/50
#  - 0s - loss: 0.0894 - val_loss: 0.1264
# Epoch 50/50
#  - 0s - loss: 0.0853 - val_loss: 0.1134

# %%
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

inv_yhat = concatenate((yhat, test_X[:, 1:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]

test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, 1:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]

rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 19689.800

# %% [markdown]
# This version is trained on ten years of data with 100 epochs.

# %%
# split into train and test sets
values = reframed.values
n_train_months = 10 * 12
train = values[:n_train_months, :]
test = values[n_train_months:, :]
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)

# design network
model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
# fit network
history = model.fit(train_X, train_y, epochs=100, batch_size=72, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# make a prediction
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
# invert scaling for forecast
inv_yhat = concatenate((yhat, test_X[:, 1:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, 1:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# (120, 1, 5) (120,) (22, 1, 5) (22,)
# Train on 120 samples, validate on 22 samples
# Epoch 1/100
#  - 7s - loss: 0.3769 - val_loss: 0.9391
# Epoch 2/100
#  - 0s - loss: 0.3611 - val_loss: 0.9178
# Epoch 3/100
#  - 0s - loss: 0.3458 - val_loss: 0.8970
# Epoch 4/100
#  - 0s - loss: 0.3310 - val_loss: 0.8754
# Epoch 5/100
#  - 0s - loss: 0.3159 - val_loss: 0.8537
# Epoch 6/100
#  - 0s - loss: 0.3016 - val_loss: 0.8320
# Epoch 7/100
#  - 0s - loss: 0.2883 - val_loss: 0.8104
# Epoch 8/100
#  - 0s - loss: 0.2761 - val_loss: 0.7888
# Epoch 9/100
#  - 0s - loss: 0.2647 - val_loss: 0.7674
# Epoch 10/100
#  - 0s - loss: 0.2544 - val_loss: 0.7461
# Epoch 11/100
#  - 0s - loss: 0.2461 - val_loss: 0.7254
# Epoch 12/100
#  - 0s - loss: 0.2388 - val_loss: 0.7051
# Epoch 13/100
#  - 0s - loss: 0.2326 - val_loss: 0.6852
# Epoch 14/100
#  - 0s - loss: 0.2276 - val_loss: 0.6661
# Epoch 15/100
#  - 0s - loss: 0.2233 - val_loss: 0.6475
# Epoch 16/100
#  - 0s - loss: 0.2190 - val_loss: 0.6294
# Epoch 17/100
#  - 0s - loss: 0.2147 - val_loss: 0.6118
# Epoch 18/100
#  - 0s - loss: 0.2105 - val_loss: 0.5943
# Epoch 19/100
#  - 0s - loss: 0.2062 - val_loss: 0.5772
# Epoch 20/100
#  - 0s - loss: 0.2020 - val_loss: 0.5602
# Epoch 21/100
#  - 0s - loss: 0.1978 - val_loss: 0.5434
# Epoch 22/100
#  - 0s - loss: 0.1937 - val_loss: 0.5266
# Epoch 23/100
#  - 0s - loss: 0.1895 - val_loss: 0.5099
# Epoch 24/100
#  - 0s - loss: 0.1855 - val_loss: 0.4934
# Epoch 25/100
#  - 0s - loss: 0.1815 - val_loss: 0.4770
# Epoch 26/100
#  - 0s - loss: 0.1774 - val_loss: 0.4605
# Epoch 27/100
#  - 0s - loss: 0.1734 - val_loss: 0.4442
# Epoch 28/100
#  - 0s - loss: 0.1694 - val_loss: 0.4278
# Epoch 29/100
#  - 0s - loss: 0.1655 - val_loss: 0.4114
# Epoch 30/100
#  - 0s - loss: 0.1615 - val_loss: 0.3950
# Epoch 31/100
#  - 0s - loss: 0.1576 - val_loss: 0.3787
# Epoch 32/100
#  - 0s - loss: 0.1538 - val_loss: 0.3627
# Epoch 33/100
#  - 0s - loss: 0.1500 - val_loss: 0.3467
# Epoch 34/100
#  - 0s - loss: 0.1462 - val_loss: 0.3309
# Epoch 35/100
#  - 0s - loss: 0.1424 - val_loss: 0.3152
# Epoch 36/100
#  - 0s - loss: 0.1386 - val_loss: 0.2996
# Epoch 37/100
#  - 0s - loss: 0.1347 - val_loss: 0.2839
# Epoch 38/100
#  - 0s - loss: 0.1308 - val_loss: 0.2682
# Epoch 39/100
#  - 0s - loss: 0.1268 - val_loss: 0.2525
# Epoch 40/100
#  - 0s - loss: 0.1228 - val_loss: 0.2367
# Epoch 41/100
#  - 0s - loss: 0.1188 - val_loss: 0.2210
# Epoch 42/100
#  - 0s - loss: 0.1148 - val_loss: 0.2053
# Epoch 43/100
#  - 0s - loss: 0.1107 - val_loss: 0.1895
# Epoch 44/100
#  - 0s - loss: 0.1066 - val_loss: 0.1738
# Epoch 45/100
#  - 0s - loss: 0.1025 - val_loss: 0.1580
# Epoch 46/100
#  - 0s - loss: 0.0985 - val_loss: 0.1424
# Epoch 47/100
#  - 0s - loss: 0.0945 - val_loss: 0.1278
# Epoch 48/100
#  - 0s - loss: 0.0905 - val_loss: 0.1141
# Epoch 49/100
#  - 0s - loss: 0.0866 - val_loss: 0.1008
# Epoch 50/100
#  - 0s - loss: 0.0829 - val_loss: 0.0881
# Epoch 51/100
#  - 0s - loss: 0.0791 - val_loss: 0.0762
# Epoch 52/100
#  - 0s - loss: 0.0753 - val_loss: 0.0652
# Epoch 53/100
#  - 0s - loss: 0.0713 - val_loss: 0.0568
# Epoch 54/100
#  - 0s - loss: 0.0675 - val_loss: 0.0508
# Epoch 55/100
#  - 0s - loss: 0.0636 - val_loss: 0.0476
# Epoch 56/100
#  - 0s - loss: 0.0598 - val_loss: 0.0449
# Epoch 57/100
#  - 0s - loss: 0.0559 - val_loss: 0.0426
# Epoch 58/100
#  - 0s - loss: 0.0520 - val_loss: 0.0409
# Epoch 59/100
#  - 0s - loss: 0.0483 - val_loss: 0.0404
# Epoch 60/100
#  - 0s - loss: 0.0449 - val_loss: 0.0407
# Epoch 61/100
#  - 0s - loss: 0.0416 - val_loss: 0.0411
# Epoch 62/100
#  - 0s - loss: 0.0390 - val_loss: 0.0421
# Epoch 63/100
#  - 0s - loss: 0.0374 - val_loss: 0.0432
# Epoch 64/100
#  - 0s - loss: 0.0365 - val_loss: 0.0444
# Epoch 65/100
#  - 0s - loss: 0.0360 - val_loss: 0.0457
# Epoch 66/100
#  - 0s - loss: 0.0357 - val_loss: 0.0472
# Epoch 67/100
#  - 0s - loss: 0.0356 - val_loss: 0.0489
# Epoch 68/100
#  - 0s - loss: 0.0354 - val_loss: 0.0508
# Epoch 69/100
#  - 0s - loss: 0.0354 - val_loss: 0.0527
# Epoch 70/100
#  - 0s - loss: 0.0354 - val_loss: 0.0547
# Epoch 71/100
#  - 0s - loss: 0.0354 - val_loss: 0.0566
# Epoch 72/100
#  - 0s - loss: 0.0354 - val_loss: 0.0582
# Epoch 73/100
#  - 0s - loss: 0.0354 - val_loss: 0.0594
# Epoch 74/100
#  - 0s - loss: 0.0355 - val_loss: 0.0603
# Epoch 75/100
#  - 0s - loss: 0.0355 - val_loss: 0.0606
# Epoch 76/100
#  - 0s - loss: 0.0355 - val_loss: 0.0606
# Epoch 77/100
#  - 0s - loss: 0.0354 - val_loss: 0.0603
# Epoch 78/100
#  - 0s - loss: 0.0354 - val_loss: 0.0596
# Epoch 79/100
#  - 0s - loss: 0.0353 - val_loss: 0.0588
# Epoch 80/100
#  - 0s - loss: 0.0352 - val_loss: 0.0579
# Epoch 81/100
#  - 0s - loss: 0.0351 - val_loss: 0.0570
# Epoch 82/100
#  - 0s - loss: 0.0351 - val_loss: 0.0565
# Epoch 83/100
#  - 0s - loss: 0.0351 - val_loss: 0.0561
# Epoch 84/100
#  - 0s - loss: 0.0350 - val_loss: 0.0559
# Epoch 85/100
#  - 0s - loss: 0.0350 - val_loss: 0.0558
# Epoch 86/100
#  - 0s - loss: 0.0350 - val_loss: 0.0558
# Epoch 87/100
#  - 0s - loss: 0.0349 - val_loss: 0.0559
# Epoch 88/100
#  - 0s - loss: 0.0349 - val_loss: 0.0560
# Epoch 89/100
#  - 0s - loss: 0.0349 - val_loss: 0.0560
# Epoch 90/100
#  - 0s - loss: 0.0349 - val_loss: 0.0561
# Epoch 91/100
#  - 0s - loss: 0.0349 - val_loss: 0.0562
# Epoch 92/100
#  - 0s - loss: 0.0349 - val_loss: 0.0563
# Epoch 93/100
#  - 0s - loss: 0.0348 - val_loss: 0.0564
# Epoch 94/100
#  - 0s - loss: 0.0348 - val_loss: 0.0565
# Epoch 95/100
#  - 0s - loss: 0.0348 - val_loss: 0.0566
# Epoch 96/100
#  - 0s - loss: 0.0348 - val_loss: 0.0567
# Epoch 97/100
#  - 0s - loss: 0.0347 - val_loss: 0.0569
# Epoch 98/100
#  - 0s - loss: 0.0347 - val_loss: 0.0571
# Epoch 99/100
#  - 0s - loss: 0.0347 - val_loss: 0.0573
# Epoch 100/100
#  - 0s - loss: 0.0347 - val_loss: 0.0576
# Test RMSE: 0.068

# %%
This version adds an extra hidden layer with 50 epochs.

# %%
# split into train and test sets
values = reframed.values
n_train_months = 10 * 12
train = values[:n_train_months, :]
test = values[n_train_months:, :]
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)

# design network
model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(5))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
# fit network
history = model.fit(train_X, train_y, epochs=50, batch_size=72, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# make a prediction
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
# invert scaling for forecast
inv_yhat = concatenate((yhat, test_X[:, 1:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, 1:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# (120, 1, 5) (120,) (22, 1, 5) (22,)
# Train on 120 samples, validate on 22 samples
# Epoch 1/50
#  - 4s - loss: 0.3127 - val_loss: 0.7588
# Epoch 2/50
#  - 0s - loss: 0.2851 - val_loss: 0.7224
# Epoch 3/50
#  - 0s - loss: 0.2586 - val_loss: 0.6854
# Epoch 4/50
#  - 0s - loss: 0.2339 - val_loss: 0.6484
# Epoch 5/50
#  - 0s - loss: 0.2121 - val_loss: 0.6111
# Epoch 6/50
#  - 0s - loss: 0.1941 - val_loss: 0.5742
# Epoch 7/50
#  - 0s - loss: 0.1807 - val_loss: 0.5386
# Epoch 8/50
#  - 0s - loss: 0.1721 - val_loss: 0.5048
# Epoch 9/50
#  - 0s - loss: 0.1659 - val_loss: 0.4730
# Epoch 10/50
#  - 0s - loss: 0.1603 - val_loss: 0.4426
# Epoch 11/50
#  - 0s - loss: 0.1555 - val_loss: 0.4138
# Epoch 12/50
#  - 0s - loss: 0.1511 - val_loss: 0.3867
# Epoch 13/50
#  - 0s - loss: 0.1472 - val_loss: 0.3611
# Epoch 14/50
#  - 0s - loss: 0.1434 - val_loss: 0.3369
# Epoch 15/50
#  - 0s - loss: 0.1392 - val_loss: 0.3135
# Epoch 16/50
#  - 0s - loss: 0.1348 - val_loss: 0.2909
# Epoch 17/50
#  - 0s - loss: 0.1305 - val_loss: 0.2691
# Epoch 18/50
#  - 0s - loss: 0.1262 - val_loss: 0.2483
# Epoch 19/50
#  - 0s - loss: 0.1218 - val_loss: 0.2282
# Epoch 20/50
#  - 0s - loss: 0.1174 - val_loss: 0.2088
# Epoch 21/50
#  - 0s - loss: 0.1129 - val_loss: 0.1902
# Epoch 22/50
#  - 0s - loss: 0.1082 - val_loss: 0.1721
# Epoch 23/50
#  - 0s - loss: 0.1034 - val_loss: 0.1546
# Epoch 24/50
#  - 0s - loss: 0.0986 - val_loss: 0.1378
# Epoch 25/50
#  - 0s - loss: 0.0935 - val_loss: 0.1226
# Epoch 26/50
#  - 0s - loss: 0.0883 - val_loss: 0.1085
# Epoch 27/50
#  - 0s - loss: 0.0829 - val_loss: 0.0951
# Epoch 28/50
#  - 0s - loss: 0.0778 - val_loss: 0.0827
# Epoch 29/50
#  - 0s - loss: 0.0726 - val_loss: 0.0712
# Epoch 30/50
#  - 0s - loss: 0.0674 - val_loss: 0.0624
# Epoch 31/50
#  - 0s - loss: 0.0622 - val_loss: 0.0557
# Epoch 32/50
#  - 0s - loss: 0.0571 - val_loss: 0.0511
# Epoch 33/50
#  - 0s - loss: 0.0527 - val_loss: 0.0477
# Epoch 34/50
#  - 0s - loss: 0.0490 - val_loss: 0.0454
# Epoch 35/50
#  - 0s - loss: 0.0462 - val_loss: 0.0441
# Epoch 36/50
#  - 0s - loss: 0.0445 - val_loss: 0.0440
# Epoch 37/50
#  - 0s - loss: 0.0436 - val_loss: 0.0446
# Epoch 38/50
#  - 0s - loss: 0.0434 - val_loss: 0.0454
# Epoch 39/50
#  - 0s - loss: 0.0433 - val_loss: 0.0462
# Epoch 40/50
#  - 0s - loss: 0.0432 - val_loss: 0.0472
# Epoch 41/50
#  - 0s - loss: 0.0431 - val_loss: 0.0483
# Epoch 42/50
#  - 0s - loss: 0.0429 - val_loss: 0.0491
# Epoch 43/50
#  - 0s - loss: 0.0426 - val_loss: 0.0497
# Epoch 44/50
#  - 0s - loss: 0.0423 - val_loss: 0.0500
# Epoch 45/50
#  - 0s - loss: 0.0418 - val_loss: 0.0500
# Epoch 46/50
#  - 0s - loss: 0.0414 - val_loss: 0.0499
# Epoch 47/50
#  - 0s - loss: 0.0409 - val_loss: 0.0495
# Epoch 48/50
#  - 0s - loss: 0.0405 - val_loss: 0.0490
# Epoch 49/50
#  - 0s - loss: 0.0400 - val_loss: 0.0483
# Epoch 50/50
#  - 0s - loss: 0.0395 - val_loss: 0.0477
# Test RMSE: 0.055

# %% [markdown]
# This version is the same as above but uses a batch size of 24.

# %%
# split into train and test sets
values = reframed.values
n_train_months = 10 * 12
train = values[:n_train_months, :]
test = values[n_train_months:, :]
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)

# design network
model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(5))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
# fit network
history = model.fit(train_X, train_y, epochs=50, batch_size=24, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# make a prediction
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
# invert scaling for forecast
inv_yhat = concatenate((yhat, test_X[:, 1:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, 1:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# (120, 1, 5) (120,) (22, 1, 5) (22,)
# Train on 120 samples, validate on 22 samples
# Epoch 1/50
#  - 5s - loss: 0.3041 - val_loss: 0.8893
# Epoch 2/50
#  - 0s - loss: 0.2861 - val_loss: 0.8457
# Epoch 3/50
#  - 0s - loss: 0.2732 - val_loss: 0.8061
# Epoch 4/50
#  - 0s - loss: 0.2625 - val_loss: 0.7700
# Epoch 5/50
#  - 0s - loss: 0.2522 - val_loss: 0.7354
# Epoch 6/50
#  - 0s - loss: 0.2416 - val_loss: 0.7008
# Epoch 7/50
#  - 0s - loss: 0.2315 - val_loss: 0.6670
# Epoch 8/50
#  - 0s - loss: 0.2214 - val_loss: 0.6331
# Epoch 9/50
#  - 0s - loss: 0.2112 - val_loss: 0.5992
# Epoch 10/50
#  - 0s - loss: 0.2013 - val_loss: 0.5650
# Epoch 11/50
#  - 0s - loss: 0.1911 - val_loss: 0.5301
# Epoch 12/50
#  - 0s - loss: 0.1810 - val_loss: 0.4946
# Epoch 13/50
#  - 0s - loss: 0.1706 - val_loss: 0.4580
# Epoch 14/50
#  - 0s - loss: 0.1599 - val_loss: 0.4205
# Epoch 15/50
#  - 0s - loss: 0.1490 - val_loss: 0.3823
# Epoch 16/50
#  - 0s - loss: 0.1378 - val_loss: 0.3434
# Epoch 17/50
#  - 0s - loss: 0.1263 - val_loss: 0.3040
# Epoch 18/50
#  - 0s - loss: 0.1145 - val_loss: 0.2649
# Epoch 19/50
#  - 0s - loss: 0.1021 - val_loss: 0.2246
# Epoch 20/50
#  - 0s - loss: 0.0891 - val_loss: 0.1822
# Epoch 21/50
#  - 0s - loss: 0.0751 - val_loss: 0.1365
# Epoch 22/50
#  - 0s - loss: 0.0606 - val_loss: 0.0905
# Epoch 23/50
#  - 0s - loss: 0.0480 - val_loss: 0.0512
# Epoch 24/50
#  - 0s - loss: 0.0406 - val_loss: 0.0406
# Epoch 25/50
#  - 0s - loss: 0.0385 - val_loss: 0.0492
# Epoch 26/50
#  - 0s - loss: 0.0373 - val_loss: 0.0515
# Epoch 27/50
#  - 0s - loss: 0.0367 - val_loss: 0.0499
# Epoch 28/50
#  - 0s - loss: 0.0369 - val_loss: 0.0500
# Epoch 29/50
#  - 0s - loss: 0.0366 - val_loss: 0.0518
# Epoch 30/50
#  - 0s - loss: 0.0361 - val_loss: 0.0537
# Epoch 31/50
#  - 0s - loss: 0.0358 - val_loss: 0.0539
# Epoch 32/50
#  - 0s - loss: 0.0353 - val_loss: 0.0525
# Epoch 33/50
#  - 0s - loss: 0.0349 - val_loss: 0.0504
# Epoch 34/50
#  - 0s - loss: 0.0347 - val_loss: 0.0497
# Epoch 35/50
#  - 0s - loss: 0.0345 - val_loss: 0.0507
# Epoch 36/50
#  - 0s - loss: 0.0343 - val_loss: 0.0512
# Epoch 37/50
#  - 0s - loss: 0.0342 - val_loss: 0.0513
# Epoch 38/50
#  - 0s - loss: 0.0340 - val_loss: 0.0512
# Epoch 39/50
#  - 0s - loss: 0.0339 - val_loss: 0.0514
# Epoch 40/50
#  - 0s - loss: 0.0337 - val_loss: 0.0518
# Epoch 41/50
#  - 0s - loss: 0.0335 - val_loss: 0.0522
# Epoch 42/50
#  - 0s - loss: 0.0334 - val_loss: 0.0528
# Epoch 43/50
#  - 0s - loss: 0.0333 - val_loss: 0.0529
# Epoch 44/50
#  - 0s - loss: 0.0333 - val_loss: 0.0534
# Epoch 45/50
#  - 0s - loss: 0.0332 - val_loss: 0.0542
# Epoch 46/50
#  - 0s - loss: 0.0331 - val_loss: 0.0539
# Epoch 47/50
#  - 0s - loss: 0.0330 - val_loss: 0.0539
# Epoch 48/50
#  - 0s - loss: 0.0330 - val_loss: 0.0550
# Epoch 49/50
#  - 0s - loss: 0.0329 - val_loss: 0.0554
# Epoch 50/50
#  - 0s - loss: 0.0328 - val_loss: 0.0555
# Test RMSE: 0.068

# %% [markdown]
# This model uses 25 nodes, three hidden layers, 50 epochs, and a batch size of 10

# %%
# split into train and test sets
values = reframed.values
n_train_months = 10 * 12
train = values[:n_train_months, :]
test = values[n_train_months:, :]
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)

# design network
model = Sequential()
model.add(LSTM(25, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(5))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
# fit network
history = model.fit(train_X, train_y, epochs=50, batch_size=10, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# make a prediction
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
# invert scaling for forecast
inv_yhat = concatenate((yhat, test_X[:, 1:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, 1:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# (120, 1, 5) (120,) (22, 1, 5) (22,)
# Train on 120 samples, validate on 22 samples
# Epoch 1/50
#  - 4s - loss: 0.3733 - val_loss: 0.8575
# Epoch 2/50
#  - 0s - loss: 0.2506 - val_loss: 0.7027
# Epoch 3/50
#  - 0s - loss: 0.1980 - val_loss: 0.5965
# Epoch 4/50
#  - 0s - loss: 0.1821 - val_loss: 0.5172
# Epoch 5/50
#  - 0s - loss: 0.1635 - val_loss: 0.4467
# Epoch 6/50
#  - 0s - loss: 0.1418 - val_loss: 0.3767
# Epoch 7/50
#  - 0s - loss: 0.1173 - val_loss: 0.2998
# Epoch 8/50
#  - 0s - loss: 0.0921 - val_loss: 0.2176
# Epoch 9/50
#  - 0s - loss: 0.0663 - val_loss: 0.1336
# Epoch 10/50
#  - 0s - loss: 0.0442 - val_loss: 0.0577
# Epoch 11/50
#  - 0s - loss: 0.0441 - val_loss: 0.0440
# Epoch 12/50
#  - 0s - loss: 0.0398 - val_loss: 0.0450
# Epoch 13/50
#  - 0s - loss: 0.0395 - val_loss: 0.0420
# Epoch 14/50
#  - 0s - loss: 0.0385 - val_loss: 0.0412
# Epoch 15/50
#  - 0s - loss: 0.0375 - val_loss: 0.0412
# Epoch 16/50
#  - 0s - loss: 0.0368 - val_loss: 0.0408
# Epoch 17/50
#  - 0s - loss: 0.0361 - val_loss: 0.0403
# Epoch 18/50
#  - 0s - loss: 0.0357 - val_loss: 0.0406
# Epoch 19/50
#  - 0s - loss: 0.0353 - val_loss: 0.0416
# Epoch 20/50
#  - 0s - loss: 0.0350 - val_loss: 0.0430
# Epoch 21/50
#  - 0s - loss: 0.0347 - val_loss: 0.0418
# Epoch 22/50
#  - 0s - loss: 0.0343 - val_loss: 0.0450
# Epoch 23/50
#  - 0s - loss: 0.0344 - val_loss: 0.0446
# Epoch 24/50
#  - 0s - loss: 0.0340 - val_loss: 0.0460
# Epoch 25/50
#  - 0s - loss: 0.0339 - val_loss: 0.0454
# Epoch 26/50
#  - 0s - loss: 0.0338 - val_loss: 0.0476
# Epoch 27/50
#  - 0s - loss: 0.0335 - val_loss: 0.0501
# Epoch 28/50
#  - 0s - loss: 0.0334 - val_loss: 0.0487
# Epoch 29/50
#  - 0s - loss: 0.0332 - val_loss: 0.0490
# Epoch 30/50
#  - 0s - loss: 0.0332 - val_loss: 0.0492
# Epoch 31/50
#  - 0s - loss: 0.0330 - val_loss: 0.0506
# Epoch 32/50
#  - 0s - loss: 0.0329 - val_loss: 0.0513
# Epoch 33/50
#  - 0s - loss: 0.0328 - val_loss: 0.0518
# Epoch 34/50
#  - 0s - loss: 0.0327 - val_loss: 0.0520
# Epoch 35/50
#  - 0s - loss: 0.0326 - val_loss: 0.0515
# Epoch 36/50
#  - 0s - loss: 0.0325 - val_loss: 0.0531
# Epoch 37/50
#  - 0s - loss: 0.0324 - val_loss: 0.0540
# Epoch 38/50
#  - 0s - loss: 0.0323 - val_loss: 0.0534
# Epoch 39/50
#  - 0s - loss: 0.0322 - val_loss: 0.0549
# Epoch 40/50
#  - 0s - loss: 0.0320 - val_loss: 0.0558
# Epoch 41/50
#  - 0s - loss: 0.0320 - val_loss: 0.0548
# Epoch 42/50
#  - 0s - loss: 0.0318 - val_loss: 0.0571
# Epoch 43/50
#  - 0s - loss: 0.0318 - val_loss: 0.0569
# Epoch 44/50
#  - 0s - loss: 0.0316 - val_loss: 0.0560
# Epoch 45/50
#  - 0s - loss: 0.0320 - val_loss: 0.0569
# Epoch 46/50
#  - 0s - loss: 0.0316 - val_loss: 0.0579
# Epoch 47/50
#  - 0s - loss: 0.0320 - val_loss: 0.0567
# Epoch 48/50
#  - 0s - loss: 0.0314 - val_loss: 0.0574
# Epoch 49/50
#  - 0s - loss: 0.0321 - val_loss: 0.0572
# Epoch 50/50
#  - 0s - loss: 0.0313 - val_loss: 0.0620
# Test RMSE: 0.077

# %% [markdown]
# The 'projections.csv' file has projections for unemployment, income, population and interest rates. Actual values were included when available. Projections for unemployment and interest rates where held at the same values as the last actual values available. Income and population were projected based on the trend of the past five years.

# %%
projections_df = pd.read_csv('projections.csv')
projections_df.head()
# Out:
#       Date   Price  Unemployment  Income  Population  Interest
# 0  1/31/20  310000           2.7   83768     2053000      3.62
# 1  2/29/20  325000           2.6   83768     2053000      3.47
# 2  3/31/20  335000           3.8   83768     2053000      3.45
# 3  4/30/20  330000          11.8   83768     2053000      3.31
# 4  5/31/20  332250          10.4   83768     2053000      3.23

# %%
projections_df['Date'] = pd.to_datetime(projections_df['Date'])
projections_df.set_index('Date', inplace=True)

projections_values = projections_df.values
# ensure all data is float
projections_values = projections_values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
projections_scaled = scaler.fit_transform(projections_values)
# frame as supervised learning
projections_reframed = series_to_supervised(projections_scaled, 1, 1)
# drop columns we don't want to predict
projections_reframed.drop(projections_reframed.columns[[6, 7, 8, 9]], axis=1, inplace=True)
print(projections_reframed.head())
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)   var1(t)
# 1   0.000000   0.010870        0.0        0.0   1.000000  0.037485
# 2   0.037485   0.000000        0.0        0.0   0.840426  0.062474
# 3   0.062474   0.130435        0.0        0.0   0.819149  0.049979
# 4   0.049979   1.000000        0.0        0.0   0.670213  0.055602
# 5   0.055602   0.847826        0.0        0.0   0.585107  0.087464

# %%
# split into train and test sets
values = reframed.values
n_train_months = 10 * 12
train = values[:, :]
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))

# split into train and test sets
projections_values = projections_reframed.values
test = projections_values[:, :]
# split into input and outputs
projections_X, projections_y = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
projections_X = projections_X.reshape((projections_X.shape[0], 1, projections_X.shape[1]))
print(train_X.shape, train_y.shape, projections_X.shape, projections_y.shape)


# design network
model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(5))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
# fit network
history = model.fit(train_X, train_y, epochs=50, batch_size=72, validation_data=(projections_X, projections_y), verbose=2, shuffle=False)
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='projections')
pyplot.legend()
pyplot.show()

# make a prediction
yhat = model.predict(projections_X)
projections_X = projections_X.reshape((projections_X.shape[0], projections_X.shape[2]))
# invert scaling for forecast
inv_yhat = concatenate((yhat, projections_X[:, 1:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]

# invert scaling for actual
projections_y = projections_y.reshape((len(projections_y), 1))
inv_y = concatenate((projections_y, projections_X[:, 1:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# (142, 1, 5) (142,) (35, 1, 5) (35,)
# Train on 142 samples, validate on 35 samples
# Epoch 1/50
#  - 7s - loss: 0.4151 - val_loss: 0.4552
# Epoch 2/50
#  - 0s - loss: 0.4028 - val_loss: 0.4423
# Epoch 3/50
#  - 0s - loss: 0.3898 - val_loss: 0.4293
# Epoch 4/50
#  - 0s - loss: 0.3770 - val_loss: 0.4163
# Epoch 5/50
#  - 0s - loss: 0.3643 - val_loss: 0.4031
# Epoch 6/50
#  - 0s - loss: 0.3518 - val_loss: 0.3897
# Epoch 7/50
#  - 0s - loss: 0.3396 - val_loss: 0.3769
# Epoch 8/50
#  - 0s - loss: 0.3279 - val_loss: 0.3647
# Epoch 9/50
#  - 0s - loss: 0.3164 - val_loss: 0.3524
# Epoch 10/50
#  - 0s - loss: 0.3053 - val_loss: 0.3413
# Epoch 11/50
#  - 0s - loss: 0.2953 - val_loss: 0.3300
# Epoch 12/50
#  - 0s - loss: 0.2858 - val_loss: 0.3187
# Epoch 13/50
#  - 0s - loss: 0.2773 - val_loss: 0.3084
# Epoch 14/50
#  - 0s - loss: 0.2696 - val_loss: 0.2983
# Epoch 15/50
#  - 0s - loss: 0.2626 - val_loss: 0.2884
# Epoch 16/50
#  - 0s - loss: 0.2560 - val_loss: 0.2790
# Epoch 17/50
#  - 0s - loss: 0.2498 - val_loss: 0.2697
# Epoch 18/50
#  - 0s - loss: 0.2439 - val_loss: 0.2607
# Epoch 19/50
#  - 0s - loss: 0.2380 - val_loss: 0.2521
# Epoch 20/50
#  - 0s - loss: 0.2321 - val_loss: 0.2439
# Epoch 21/50
#  - 0s - loss: 0.2262 - val_loss: 0.2362
# Epoch 22/50
#  - 0s - loss: 0.2203 - val_loss: 0.2286
# Epoch 23/50
#  - 0s - loss: 0.2145 - val_loss: 0.2211
# Epoch 24/50
#  - 0s - loss: 0.2087 - val_loss: 0.2135
# Epoch 25/50
#  - 0s - loss: 0.2029 - val_loss: 0.2059
# Epoch 26/50
#  - 0s - loss: 0.1971 - val_loss: 0.1981
# Epoch 27/50
#  - 0s - loss: 0.1913 - val_loss: 0.1903
# Epoch 28/50
#  - 0s - loss: 0.1856 - val_loss: 0.1826
# Epoch 29/50
#  - 0s - loss: 0.1800 - val_loss: 0.1752
# Epoch 30/50
#  - 0s - loss: 0.1743 - val_loss: 0.1678
# Epoch 31/50
#  - 0s - loss: 0.1684 - val_loss: 0.1602
# Epoch 32/50
#  - 0s - loss: 0.1625 - val_loss: 0.1525
# Epoch 33/50
#  - 0s - loss: 0.1564 - val_loss: 0.1447
# Epoch 34/50
#  - 0s - loss: 0.1502 - val_loss: 0.1368
# Epoch 35/50
#  - 0s - loss: 0.1441 - val_loss: 0.1288
# Epoch 36/50
#  - 0s - loss: 0.1380 - val_loss: 0.1206
# Epoch 37/50
#  - 0s - loss: 0.1318 - val_loss: 0.1124
# Epoch 38/50
#  - 0s - loss: 0.1258 - val_loss: 0.1042
# Epoch 39/50
#  - 0s - loss: 0.1198 - val_loss: 0.0969
# Epoch 40/50
#  - 0s - loss: 0.1140 - val_loss: 0.0906
# Epoch 41/50
#  - 0s - loss: 0.1081 - val_loss: 0.0854
# Epoch 42/50
#  - 0s - loss: 0.1023 - val_loss: 0.0811
# Epoch 43/50
#  - 0s - loss: 0.0967 - val_loss: 0.0774
# Epoch 44/50
#  - 0s - loss: 0.0912 - val_loss: 0.0747
# Epoch 45/50
#  - 0s - loss: 0.0858 - val_loss: 0.0726
# Epoch 46/50
#  - 0s - loss: 0.0808 - val_loss: 0.0711
# Epoch 47/50
#  - 0s - loss: 0.0762 - val_loss: 0.0698
# Epoch 48/50
#  - 0s - loss: 0.0723 - val_loss: 0.0686
# Epoch 49/50
#  - 0s - loss: 0.0685 - val_loss: 0.0669
# Epoch 50/50
#  - 0s - loss: 0.0645 - val_loss: 0.0646
# Test RMSE: 31300.041

# %% [markdown]
# A list of the predicted home prices.

# %%
inv_yhat
# Out:
# array([368992.94, 375053.06, 375040.2 , 354265.84, 359733.03, 368597.47,
#        375926.53, 382303.  , 382411.94, 388305.62, 388649.4 , 392133.66,
#        483135.38, 490461.7 , 498701.66, 512969.22, 516608.03, 519413.97,
#        522276.62, 525196.9 , 528176.06, 531215.4 , 534315.3 , 537477.3 ,
#        642589.4 , 645966.3 , 649406.3 , 652909.8 , 656478.3 , 660112.2 ,
#        663812.3 , 667579.5 , 671414.94, 675319.25, 679293.2 ],
#       dtype=float32)

# %%
f = pyplot.figure()
f.set_figwidth(10)
f.set_figheight(10)
pyplot.plot(projections_df.index[1:], inv_yhat, label='Model Predictions')
pyplot.plot(projections_df.index[1:], projections_df['Price'][1:], label='Projections before Modeling')

# pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
